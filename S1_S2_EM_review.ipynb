# %% [markdown]
# <a href="https://colab.research.google.com/github/njkanexstudents2026/Economic-Modeling/blob/main/S1_S2_EM_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Modelling Session 1 Class Examples
# ### Simple Point Class
# - initialize the point
# - add str method to print the point
# - add repr and lt
# - sorted a list of points
# ###Simple Color Point Class
# - showcase inheritance
# - explain how to import
# - added name == "main" to guard against import runs
# - sorted list of color points
